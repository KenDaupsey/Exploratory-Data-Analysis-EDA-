# %% [markdown]
# <a href="https://colab.research.google.com/github/KenDaupsey/Exploratory-Data-Analysis-EDA-/blob/main/Exploratory_Data_Analysis_(EDA)_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Exploratory Data Analysis Example 1
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data from GitHub URL
url = "https://raw.githubusercontent.com/KenDaupsey/Exploratory-Data-Analysis-EDA-/main/hsb2%7Edata.csv"
df = pd.read_csv(url)

# %%
# We set the plotting style for our images, which will be produced by the seaborn library.
# Set plotting style

sns.set_style('whitegrid')

# %%
# Print columns
print(df.columns)
# Out:
# Index(['id', 'female', 'race', 'ses', 'schtyp', 'prog', 'read', 'write',
#        'math', 'science', 'socst'],
#       dtype='object')

# %%
# Summary statistics
print(df.describe())
# Out:
#                id        read       write        math     science       socst
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000   52.230000   52.775000   52.645000   51.850000   52.405000
# std     57.879185   10.252937    9.478586    9.368448    9.900891   10.735793
# min      1.000000   28.000000   31.000000   33.000000   26.000000   26.000000
# 25%     50.750000   44.000000   45.750000   45.000000   44.000000   46.000000
# 50%    100.500000   50.000000   54.000000   52.000000   53.000000   52.000000
# 75%    150.250000   60.000000   60.000000   59.000000   58.000000   61.000000
# max    200.000000   76.000000   67.000000   75.000000   74.000000   71.000000

# %%
# Check for null values
print(df.isnull().sum())
# Out:
# id         0
# female     0
# race       0
# ses        0
# schtyp     0
# prog       0
# read       0
# write      0
# math       0
# science    0
# socst      0
# dtype: int64

# %%
# Distribution of numerical columns
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs = axs.flatten()
for i, col in enumerate(['read', 'write', 'math', 'science']):
    sns.histplot(df[col], ax=axs[i], kde=True)  # Use histplot for axes-level plots
plt.tight_layout()

# %%
# Count plots for categorical columns
fig, axs = plt.subplots(2,2, figsize=(12,12))
axs = axs.flatten()
for i, col in enumerate(['female', 'race', 'ses', 'schtyp']):
    sns.countplot(data=df, x=col, ax=axs[i])
plt.tight_layout()

# %%
#Below, we use boxplots to compare the distribution of the numerical variables by gender.

# Box plots for numerical columns by gender
fig, axs = plt.subplots(5,1, figsize=(8, 20))
axs = axs.flatten()
for i, col in enumerate(['read', 'write', 'math', 'science', 'socst']):
   sns.boxplot(data=df, x='female', y=col, ax=axs[i])
plt.tight_layout()

# %%
# Violin plots to visualize the distribution of a numerical dataset
sns.violinplot(data=df, x='female', y='read')
sns.violinplot(data=df, x='race', y='math')
# Out:
# <Axes: xlabel='female', ylabel='read'>

# %%
# Scatterplots
sns.scatterplot(data=df, x='read', y='write')
# Out:
# <Axes: xlabel='read', ylabel='write'>

# %%
# Correlogram to visually display the correlation coefficients
## between multiple variables in a matrix form

# Explicitly specify the value of numeric_only to silence the warning

corr_mat = df.corr(numeric_only=True)
sns.heatmap(corr_mat, annot=True)
plt.show()
